# %%
import numpy as np
import pandas as pd
import pickle
import dill
import time
from collections import Counter

from database.query import DataAccess
from bson.objectid import ObjectId
from feature_extraction.transformers import *
from database.utils import get_train_test_data 

from sklearn.metrics import roc_auc_score

# %reload_ext autoreload
# %autoreload 2

# %%
ensemble_indicators = ['sleep_ensemble_latest',
                       'physical_activity_ensemble_latest',
                       'sedentary_behaviour_ensemble_latest']
ensemble_models = []

for indicator in ensemble_indicators:
    with open('./model/%s.pkl' % indicator, 'rb') as f:
        clf = dill.load(f)
        ensemble_models.append((clf, indicator))

# %%
train_test_data = get_train_test_data()

# %%
results = {}

for _, _, X_test, y_test, indicator in train_test_data:
    results[indicator] = {}
    index = [indicator for _, indicator in ensemble_models].index(indicator + "_ensemble_latest")
    clf = ensemble_models[index][0]
    y_proba = clf.predict_proba(X_test)
    y_pred = clf.predict(X_test)
    auc = roc_auc_score(y_test, y_proba[:, 1])
    print(indicator, auc)
    
    results[indicator]['y_proba'] = y_proba[:, 1]
    results[indicator]['y_pred'] = y_pred
    results[indicator]['y_true'] = y_test
    results[indicator]['text'] = X_test
# Out:
# sleep 0.831136363636
# sedentary_behaviour 0.804333695526
# physical_activity 0.871143375681

# %%
pa = pd.DataFrame(results['physical_activity'])
false_pos = (pa.y_pred == 1) & (pa.y_true == 0)
false_neg = (pa.y_pred == 0) & (pa.y_true == 1)

pa.loc[false_neg]
# Out:
#                                                   text  y_pred   y_proba  \
# 20                          sunset hike @ dog mountain     0.0  0.211699
# 27   hillsprints workout 6weekchallenge myfitnessce...     0.0  0.388819
# 32                      p90x workout - sample workouts     0.0  0.130280
# 43   well deserved soak after yoga � � bath bathtim...     0.0  0.202382
# 53   9:30 flow & 12:00 restorative . � � yoga abbot...     0.0  0.142290
# 58   sample glutes workout ❤ ️ ❤ ️ fit fitness good...     0.0  0.432646
# 99   mixing it up this morning ! ashtanga yoga with...     0.0  0.219800
# 104  big wave maeve shredding in jiquilillo surferg...     0.0  0.277297
# 125  weekend 4 of 4 yoga as a healing modality oste...     0.0  0.428576
# 126  getting hyped about tonight's workout chestday...     0.0  0.414178
# 188  yoga class on green roof because why not ! loo...     0.0  0.462532
#
#      y_true
# 20        1
# 27        1
# 32        1
# 43        1
# 53        1
# 58        1
# 99        1
# 104       1
# 125       1
# 126       1
# 188       1

# %%
pa.loc[false_pos]
# Out:
#                                                   text  y_pred   y_proba  \
# 202  because the journey is the destination . gymti...     1.0  0.950208
# 204  leg day sample exercise video � � � � fitness ...     1.0  0.860784
# 206              problems hit the gym they all workout     1.0  0.979198
# 207  the life of a basketball mom . basketball ball...     1.0  0.781284
# 208  cardio , core , chest and back ! homegym cross...     1.0  0.974566
# 209    very difficult to do yoga around here . catyoga     1.0  0.965548
# 210  high good morning ! ! ! mornigwalk morning mor...     1.0  0.963018
# 211  look whats back at redlineconditioning sleds f...     1.0  0.742479
# 212  end result ... . . . . . fitness cardio cardio...     1.0  0.982456
# 213  its so beautiful out today ! i had to drop my ...     1.0  0.986426
# 214  summer is almost here ! get started training o...     1.0  0.979721
# 215  butcher says the type of yoga johnston taught ...     1.0  0.969578
# 216  lots of reasons to smile today ! yoga . sunshi...     1.0  0.952699
# 218   your wednesday workout schedule at tribeqqhq � �     1.0  0.911507
# 219  beautiful week exercise ! we have prenatal yog...     1.0  0.712623
# 225                                         workouts *     1.0  0.504513
# 232    sample abs workout ❤ ️ ❤ ️ fit fitness goodlife     1.0  0.685532
# 238  uphill elliptical workout fitness exercise pre...     1.0  0.860320
# 240  leg day sample exercise video � � � � fitness ...     1.0  0.860784
# 241  leg day sample exercise video � � � � fitness ...     1.0  0.860784
# 242  leg day sample exercise video � � � � fitness ...     1.0  0.860784
# 243              guy ! dm workout schedule ! sharply !     1.0  0.979884
# 244                             workout motivations :D     1.0  0.659902
# 248  this hill is one instagram post long . running...     1.0  0.972484
# 249                               dm ur diet / workout     1.0  0.541197
# 250  beginner hip hop tonight at 5 pm with � � . hi...     1.0  0.853430
# 251  toronto workouts gymgirl gym_motivation gym li...     1.0  0.937735
# 252                         morning gene . gym today ?     1.0  0.974384
# 254                     always a fun brain workout � �     1.0  0.979610
# 260  retro � � . predictably faded ; a little like ...     1.0  0.985425
# 261  asportekchallenge healthyfood gym asportek str...     1.0  0.582524
# 264  happy 39 years ! celebrate by grabbing a muscl...     1.0  0.964541
# 265         sunday morning fun @ mississauga , ontario     1.0  0.838378
# 268  my little cuddle monster at this evening's far...     1.0  0.976882
# 269  baystreet businessdistrict libertyvillage cabb...     1.0  0.821552
# 272  life is not a dress rehearsal try yoga now ! y...     1.0  0.745440
# 273  good morning from our kgms yogis ! yoga stretc...     1.0  0.514208
# 275  exactly one month until full moon beach yoga !...     1.0  0.566217
# 282  first time ever in canada 200 hour yoga teache...     1.0  0.971714
# 283                                              gym .     1.0  0.982417
# 284  going to work a day after coming back from vac...     1.0  0.983764
# 286  when the list of injury stretching is too much...     1.0  0.987512
# 288      wait till my workout tape comes out ! � � � �     1.0  0.975366
# 289  i watch your workouts on instastory and preten...     1.0  0.917487
# 290  early morning workout before the big tsdemoday...     1.0  0.988523
# 291  early morning workout before the big tsdemoday...     1.0  0.988523
# 292          sunday morning breakfast . � � glutenfree     1.0  0.935076
# 296  fitness gym workout phones soannoying @ toront...     1.0  0.980698
# 300                           gym gym gym gym gym days     1.0  0.974174
# 302   sample legs workout ❤ ️ ❤ ️ fit fitness goodlife     1.0  0.968949
# 303   sample legs workout ❤ ️ ❤ ️ fit fitness goodlife     1.0  0.968949
# 304        new workout shirt projectrock maximumeffort     1.0  0.686789
# 310  it ’ s like yoga but on a bike ... yoga bike y...     1.0  0.890238
# 311               bodyrock - the home workout movement     1.0  0.724365
# 313                       going to the gym alone sucks     1.0  0.949341
# 314  me while praying ! fit workout motivation fitf...     1.0  0.980288
# 319  saturdayshenanigans � � � � ‍ ♂ ️ � � weekendw...     1.0  0.681591
# 321  when the afrobeats take you away . tea fitness...     1.0  0.950111
# 322  pick an emoji to describe yesterday ’ s workou...     1.0  0.919550
# 323                               that's a workout lol     1.0  0.947222
#
#      y_true
# 202       0
# 204       0
# 206       0
# 207       0
# 208       0
# 209       0
# 210       0
# 211       0
# 212       0
# 213       0
# 214       0
# 215       0
# 216       0
# 218       0
# 219       0
# 225       0
# 232       0
# 238       0
# 240       0
# 241       0
# 242       0
# 243       0
# 244       0
# 248       0
# 249       0
# 250       0
# 251       0
# 252       0
# 254       0
# 260       0
# 261       0
# 264       0
# 265       0
# 268       0
# 269       0
# 272       0
# 273       0
# 275       0
# 282       0
# 283       0
# 284       0
# 286       0
# 288       0
# 289       0
# 290       0
# 291       0
# 292       0
# 296       0
# 300       0
# 302       0
# 303       0
# 304       0
# 310       0
# 311       0
# 313       0
# 314       0
# 319       0
# 321       0
# 322       0
# 323       0

# %%
pa = pd.DataFrame(results['sedentary_behaviour'])
false_pos = (pa.y_pred == 1) & (pa.y_true == 0)
false_neg = (pa.y_pred == 0) & (pa.y_true == 1)

pa.loc[false_neg]
# Out:
#                                                   text  y_pred   y_proba  \
# 2    holy fuck we pushed it to a game 7 unreal . th...     0.0  0.442229
# 3      leafs have haven't played well most of the game     0.0  0.367587
# 4      raptors on to the second round ! wethenorth � �     0.0  0.430499
# 7                 leafs on one tv , ninja on the other     0.0  0.241074
# 8    as a fan i can honestly say i will not miss re...     0.0  0.236194
# 10   leafs played a good game too ! sorry toronto c...     0.0  0.417711
# 12   ... bruins need to get a lead for a change ......     0.0  0.292988
# 14        it's like the raptors enjoy playing catch up     0.0  0.383631
# 18                              is lebron going off tn     0.0  0.273651
# 25   unless fvv is a god ... the raptors are in a l...     0.0  0.250287
# 30   great year but salty loss . leafs didn't play ...     0.0  0.370747
# 37                        time to watch pacers vs cavs     0.0  0.459268
# 50   pretty sure i ’ m the only person on twitter i...     0.0  0.309726
# 65   these two games are stressing me out . lol rap...     0.0  0.238024
# 71   leafs ' rielly exits game 7 after taking chara...     0.0  0.315726
# 73                                  raptors turning up     0.0  0.303700
# 80   raptors completely froze with the ball that qu...     0.0  0.306176
# 81      leafs give up 4 in the 3rd ... that is all � �     0.0  0.350541
# 82   the refs in the leafs / bruins game have learn...     0.0  0.324527
# 87               holy penalties brutal refs . go leafs     0.0  0.442809
# 90                              raptors fucked that up     0.0  0.240980
# 91               vintage jake gardiner tonight ! leafs     0.0  0.253035
# 93                          nice softy andersson leafs     0.0  0.231730
# 94                       all gardner ... smh ... leafs     0.0  0.329129
# 95   leafs up 4-3 with 20 to go ? ? ? never been be...     0.0  0.271735
# 96   here we go with lebron getting the calls ... a...     0.0  0.289812
# 97   it looks to me that the raptors are playing ag...     0.0  0.437053
# 98   all of a sudden , cavs have the best defence i...     0.0  0.316234
# 102  sorry laine didn't pass the puck to buff it de...     0.0  0.396697
# 103  andersen was bad , gardiner was worse . wasn ’...     0.0  0.349747
# ..                                                 ...     ...       ...
# 204  jake gardiner causing another goal ... the hat...     0.0  0.252140
# 205  oh dear , baby marchand upset , another cheap ...     0.0  0.450786
# 206         warriors are killing it woo love this team     0.0  0.431176
# 209  why i as the face off in the toronto zone ? sh...     0.0  0.228362
# 210  with jvr i bet the leafs power play in particu...     0.0  0.247423
# 211                                    nhl refs blow .     0.0  0.246973
# 212                       game of the playoffs don't @     0.0  0.248103
# 214  one of the easiest fundamentals in basketball ...     0.0  0.288365
# 217  why are you shooting a 3 ... raptors deserved ...     0.0  0.451978
# 218  this is wild action , edge of your seat type a...     0.0  0.271592
# 219  i don't know how i got through the first 20 mi...     0.0  0.378564
# 220  can we please keep ron hainsey off the ice ? t...     0.0  0.234050
# 221       leafs kill off both penalties . huge kills .     0.0  0.464793
# 224  great first quarter by the raps . demar looks ...     0.0  0.260708
# 225    wow pacers cavs going to the wire ! nbaplayoffs     0.0  0.242570
# 226      raptors deserve to lose . playing like bums .     0.0  0.233319
# 228  thank you for game 2 raptors tickets ! i can ’...     0.0  0.439338
# 230  listen to episode 97 : systems analysis with j...     0.0  0.292633
# 232  pissed i'm missing the raptors , but i got adv...     0.0  0.494644
# 234  what the hell ... you guys were up the entire ...     0.0  0.271891
# 239  if the leafs give this one up , it will 100 % ...     0.0  0.332101
# 242  it hurts my soul to watch everyone not named l...     0.0  0.335405
# 243  pissed in missing the raptors , but i got adva...     0.0  0.498797
# 251  what the hell was that . chara stopped and let...     0.0  0.496692
# 261               this pacers cavs game is a humdinger     0.0  0.482765
# 280  my son lives 80kms away . he said he heard me ...     0.0  0.245172
# 942  how many layups have the raptors missed tonigh...     0.0  0.249879
# 951  go leafs go ! enjoying a great game at bp vaug...     0.0  0.389259
# 952  enjoying another edition of on . is so good an...     0.0  0.418587
# 962  i ’ m more stressed about this raptors game ri...     0.0  0.341753
#
#      y_true
# 2       1.0
# 3       1.0
# 4       1.0
# 7       1.0
# 8       1.0
# 10      1.0
# 12      1.0
# 14      1.0
# 18      1.0
# 25      1.0
# 30      1.0
# 37      1.0
# 50      1.0
# 65      1.0
# 71      1.0
# 73      1.0
# 80      1.0
# 81      1.0
# 82      1.0
# 87      1.0
# 90      1.0
# 91      1.0
# 93      1.0
# 94      1.0
# 95      1.0
# 96      1.0
# 97      1.0
# 98      1.0
# 102     1.0
# 103     1.0
# ..      ...
# 204     1.0
# 205     1.0
# 206     1.0
# 209     1.0
# 210     1.0
# 211     1.0
# 212     1.0
# 214     1.0
# 217     1.0
# 218     1.0
# 219     1.0
# 220     1.0
# 221     1.0
# 224     1.0
# 225     1.0
# 226     1.0
# 228     1.0
# 230     1.0
# 232     1.0
# 234     1.0
# 239     1.0
# 242     1.0
# 243     1.0
# 251     1.0
# 261     1.0
# 280     1.0
# 942     1.0
# 951     1.0
# 952     1.0
# 962     1.0
#
# [93 rows x 4 columns]

# %%
pa.loc[false_pos]
# Out:
#                                                   text  y_pred   y_proba  \
# 287  the leafs were horrible at drawing penalties a...     1.0  0.566721
# 290  fucking hell , leafs love making it hard on th...     1.0  0.594239
# 303  haha just checked the score of the leafs game ...     1.0  0.855699
# 312  maaarrlleeaauuu ! ! ! leafs lead 1-0 ! ! ! tml...     1.0  0.864750
# 316  bruins are done . regroup for game 7 at home ,...     1.0  0.631482
# 321  i see a lot of leafs fans complaining about se...     1.0  0.565594
# 338                             bharatanenenu watching     1.0  0.921048
# 339  your not watching the game the jets are the on...     1.0  0.848802
# 342  if pittsburgh wins the cup this year im never ...     1.0  0.876802
# 344  lol just overheard raptors highlights in the w...     1.0  0.908397
# 345  my team lost last night in our finals . that m...     1.0  0.896954
# 349  i wasn ’ t able to watch the game last night a...     1.0  0.868292
# 350  watching the 76ers and celtics for the next te...     1.0  0.861290
# 351                  that was the worst night ever � �     1.0  0.502129
# 352                  that was fun ! mapleleafs tmltalk     1.0  0.609063
# 353  hopefully they're watching tape & trying to fi...     1.0  0.822691
# 361  i respect the hell out of everyone watching th...     1.0  0.896145
# 362                 watching this saturday morning � �     1.0  0.944888
# 365                  imagine watching this game high ?     1.0  0.894197
# 366  not a leaf fan but after watching them fall ap...     1.0  0.896692
# 367  pictured ... my faith in the leafs right now ....     1.0  0.848163
# 368  lol if meek is showing up to the sixers game t...     1.0  0.921486
# 369               any time i watch a leaf playoff loss     1.0  0.782734
# 390  nhl teams with 3-1 series lead are 268-28 ( . ...     1.0  0.780144
# 393  the worst thing about the leafs possibly losin...     1.0  0.528619
# 394  people at the game who literally are watching ...     1.0  0.874009
# 395  we're going to end this series tonight ! wethe...     1.0  0.602182
# 397  just got off the plane and saw the raptors fin...     1.0  0.855331
# 404  right on rob . i see a low scoring game and an...     1.0  0.724221
# 411  this game is about the speed and skill of leaf...     1.0  0.728050
# ..                                                 ...     ...       ...
# 833  i ’ m fully on the jets bandwagon . i ’ m just...     1.0  0.874393
# 835  the fact that my two favourite players and mig...     1.0  0.538870
# 854    jv with 2 huge put back misses late ... raptors     1.0  0.584652
# 858                    are we watching the same game ?     1.0  0.871267
# 860                           game 7 ! goleafsgo ! ! !     1.0  0.591463
# 861                           game 7 ! ! ! goleafsgo !     1.0  0.592791
# 872  this tweet is exactly how im feeling about the...     1.0  0.836607
# 874  go leafs go . . swing by and cheer on your hom...     1.0  0.700122
# 882  afternoon u watching the jets / predators seri...     1.0  0.899920
# 889    so this is what depression feels like ! raptors     1.0  0.543732
# 894  hockey is about to start and my stomach is rea...     1.0  0.758114
# 898  the bruins are going to steal a win tonight . ...     1.0  0.511311
# 900  edmonton , who ’ s watching the jets this frid...     1.0  0.826027
# 904  thanks to coach ferster and the west-k warrior...     1.0  0.822611
# 905  it was the most-watched whcd in history . peri...     1.0  0.909632
# 908  wethenorth ✅ tmltalk 4-3 bluejays 4-3 tfclive ...     1.0  0.798934
# 910  i have to return something to champs and legit...     1.0  0.671962
# 912  that ’ s a prize understatement . leafs need t...     1.0  0.501390
# 915  27.2 seconds untill game 7 ! hype tmltalk stan...     1.0  0.723199
# 917  only way toronto wins this series is if their ...     1.0  0.626218
# 918  the last time went into down 3-1 they should h...     1.0  0.790730
# 919  one of the worst things about the not advancin...     1.0  0.644302
# 926  lebron seems ready n up fr his umpteenth game ...     1.0  0.630333
# 932  i can ’ t believe i let myself become invested...     1.0  0.793373
# 939  hope the bruins are up big in game 5 so their ...     1.0  0.608233
# 944   r u dumb just cause raptors got u traded � � � �     1.0  0.521506
# 945  bruins look scared and disorganized . leafs ar...     1.0  0.750445
# 946  the leafs season is on the line this third per...     1.0  0.586706
# 961        for the mapleleafs game ! torontomapleleafs     1.0  0.652217
# 996  luca and my mom my mom keep texting me the sco...     1.0  0.563130
#
#      y_true
# 287     0.0
# 290     0.0
# 303     0.0
# 312     0.0
# 316     0.0
# 321     0.0
# 338     0.0
# 339     0.0
# 342     0.0
# 344     0.0
# 345     0.0
# 349     0.0
# 350     0.0
# 351     0.0
# 352     0.0
# 353     0.0
# 361     0.0
# 362     0.0
# 365     0.0
# 366     0.0
# 367     0.0
# 368     0.0
# 369     0.0
# 390     0.0
# 393     0.0
# 394     0.0
# 395     0.0
# 397     0.0
# 404     0.0
# 411     0.0
# ..      ...
# 833     0.0
# 835     0.0
# 854     0.0
# 858     0.0
# 860     0.0
# 861     0.0
# 872     0.0
# 874     0.0
# 882     0.0
# 889     0.0
# 894     0.0
# 898     0.0
# 900     0.0
# 904     0.0
# 905     0.0
# 908     0.0
# 910     0.0
# 912     0.0
# 915     0.0
# 917     0.0
# 918     0.0
# 919     0.0
# 926     0.0
# 932     0.0
# 939     0.0
# 944     0.0
# 945     0.0
# 946     0.0
# 961     0.0
# 996     0.0
#
# [167 rows x 4 columns]

# %%
sleep = pd.DataFrame(results['sleep'])
false_pos = (sleep.y_pred == 1) & (sleep.y_true == 0)
false_neg = (sleep.y_pred == 0) & (sleep.y_true == 1)

sleep.loc[false_neg]
# Out:
#                                                   text  y_pred   y_proba  \
# 2                    i would sleep 24 hours straight .     0.0  0.364730
# 19   almost 2am ... still awake ... need to be up i...     0.0  0.361036
# 28                          only slept for 4 hours � �     0.0  0.406703
# 42                         got like what 2 hours sleep     0.0  0.404514
# 53                                        shitty sleep     0.0  0.279658
# 87   love n ' hugs right back ! slept for about two...     0.0  0.329900
# 91                                      sleep deprived     0.0  0.316077
# 109  slept 4 hours yesterday . get 2 hours 45 mins ...     0.0  0.472065
#
#      y_true
# 2         1
# 19        1
# 28        1
# 42        1
# 53        1
# 87        1
# 91        1
# 109       1

# %%
sleep.loc[false_pos]
# Out:
#                                                   text  y_pred   y_proba  \
# 1    me , trying to be productive and useful today ...     1.0  0.759260
# 9    been getting 8 hours of sleep consistently fee...     1.0  0.750790
# 10                           12 hours of sleep � � � �     1.0  0.790751
# 12                                   15 hours of sleep     1.0  0.525085
# 15               23 hours of sleep , 1 hour of mania ?     1.0  0.796156
# 23   we both fell asleep at like 7pm � � � � 1am * ...     1.0  0.616816
# 25   lmaooo � � get sleep fr haha i'm the same when...     1.0  0.763369
# 32   i fully intended to nap for like 2 hours ... i...     1.0  0.568825
# 39   ahhh , i finally got 8 hours sleep . it took m...     1.0  0.632465
# 40                               10 hours of sleep � �     1.0  0.787086
# 43                                     i can sleep now     1.0  0.578738
# 44       gonna go to school with 4 hours of sleep nice     1.0  0.644956
# 48   left the office at 2pm est ... 13 hours later ...     1.0  0.691503
# 56   i'm more tired after 10 hours of sleep then i ...     1.0  0.745191
# 64   it might be worse then you think i have been o...     1.0  0.522173
# 74   night .. sleep .. blissful sleep is what i wis...     1.0  0.501553
# 79   how thursday evening went . glorious 10 hours ...     1.0  0.749722
# 80   too bad i can ’ t sleep until i get home from ...     1.0  0.787757
# 95   i don ’ t get how even after 9-10 hours of sle...     1.0  0.824423
# 103  slept for almost 11 hours last night .. best s...     1.0  0.701699
# 104                    needed that 13 hours of sleep .     1.0  0.728242
# 105  i want a vacation . but i would settle for 10 ...     1.0  0.666439
# 112                10 hours of uninterrupted sleep � �     1.0  0.790434
# 115  � � � � night night ... off to bed now ... sle...     1.0  0.573123
# 120  got 10 hours of sleep lastnight and can barely...     1.0  0.753481
# 124                   my sleep schedule is so fucked .     1.0  0.520725
# 125    yo i didn ’ t just sleep for 13 hours holy fuck     1.0  0.761193
# 133  2 hours of sleep putragis pakamatay na � � � �...     1.0  0.815785
#
#      y_true
# 1         0
# 9         0
# 10        0
# 12        0
# 15        0
# 23        0
# 25        0
# 32        0
# 39        0
# 40        0
# 43        0
# 44        0
# 48        0
# 56        0
# 64        0
# 74        0
# 79        0
# 80        0
# 95        0
# 103       0
# 104       0
# 105       0
# 112       0
# 115       0
# 120       0
# 124       0
# 125       0
# 133       0
